# %%
import nltk
import numpy as np
import pandas as pd
import random
from sklearn.model_selection import train_test_split
import pprint, time

# %% [markdown]
# # Download the treebank corpus from nltk

# %%
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\pakhrins\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# True

# %% [markdown]
# # Download the universal tagset from nltk

# %%
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\pakhrins\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %% [markdown]
# # reading the Treebank tagged sentences

# %%
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %% [markdown]
# # print the first two sentences along with tags

# %%
print(nltk_data[:2])
# Out:
# [[('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')], [('Mr.', 'NOUN'), ('Vinken', 'NOUN'), ('is', 'VERB'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Elsevier', 'NOUN'), ('N.V.', 'NOUN'), (',', '.'), ('the', 'DET'), ('Dutch', 'NOUN'), ('publishing', 'VERB'), ('group', 'NOUN'), ('.', '.')]]

# %% [markdown]
# # print each word with its respective tag for first two sentences

# %%
for sent in nltk_data[:2]:
  for tuple in sent:
    print(tuple)
# Out:
# ('Pierre', 'NOUN')
# ('Vinken', 'NOUN')
# (',', '.')
# ('61', 'NUM')
# ('years', 'NOUN')
# ('old', 'ADJ')
# (',', '.')
# ('will', 'VERB')
# ('join', 'VERB')
# ('the', 'DET')
# ('board', 'NOUN')
# ('as', 'ADP')
# ('a', 'DET')
# ('nonexecutive', 'ADJ')
# ('director', 'NOUN')
# ('Nov.', 'NOUN')
# ('29', 'NUM')
# ('.', '.')
# ('Mr.', 'NOUN')
# ('Vinken', 'NOUN')
# ('is', 'VERB')
# ('chairman', 'NOUN')
# ('of', 'ADP')
# ('Elsevier', 'NOUN')
# ('N.V.', 'NOUN')
# (',', '.')
# ('the', 'DET')
# ('Dutch', 'NOUN')
# ('publishing', 'VERB')
# ('group', 'NOUN')
# ('.', '.')

# %% [markdown]
# # split data into training and validation set in the ratio 80:20

# %%
train_set,test_set =train_test_split(nltk_data,train_size=0.80,test_size=0.20,random_state = 101)

# %% [markdown]
# # create list of train and test tagged words

# %%
train_tagged_words = [ tup for sent in train_set for tup in sent ]
test_tagged_words = [ tup for sent in test_set for tup in sent ]
print(len(train_tagged_words))
print(len(test_tagged_words))
# Out:
# 80310
# 20366

# %%
train_tagged_words[:5]
# Out:
# [('Drink', 'NOUN'),
#  ('Carrier', 'NOUN'),
#  ('Competes', 'VERB'),
#  ('With', 'ADP'),
#  ('Cartons', 'NOUN')]

# %% [markdown]
# # check some of the tagged words.

# %%
train_tagged_words[:5]
# Out:
# [('Drink', 'NOUN'),
#  ('Carrier', 'NOUN'),
#  ('Competes', 'VERB'),
#  ('With', 'ADP'),
#  ('Cartons', 'NOUN')]

# %% [markdown]
# # use set datatype to check how many unique tags are present in training data

# %%
tags = {tag for word,tag in train_tagged_words}
print(len(tags))
print(tags)
# Out:
# 12
# {'PRON', 'ADV', 'DET', '.', 'NOUN', 'X', 'PRT', 'ADP', 'CONJ', 'VERB', 'ADJ', 'NUM'}

# %% [markdown]
# # check total words in vocabulary

# %%
vocab = {word for word,tag in train_tagged_words}

# %%
len(vocab)
# Out:
# 11052

# %% [markdown]
# # Compute Emission Probability

# %%
def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
#     print(tag_list)
    count_tag = len(tag_list)#total number of times the passed tag occurred in train_bag
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    #now calculate the total number of times the passed word occurred as the passed tag.
    count_w_given_tag = len(w_given_tag_list)
 
     
    return (count_w_given_tag, count_tag)

# %%
check_values = word_given_tag('sold', 'VERB')
check_values
# Out:
# [('Competes', 'VERB'), ('had', 'VERB'), ('sold', 'VERB'), ('lauded', 'VERB'), ('creating', 'VERB'), ('trained', 'VERB'), ('pursue', 'VERB'), ('says', 'VERB'), ('shall', 'VERB'), ('be', 'VERB'), ('said', 'VERB'), ('is', 'VERB'), ('had', 'VERB'), ('requested', 'VERB'), ('covered', 'VERB'), ('passed', 'VERB'), ('designed', 'VERB'), ('make', 'VERB'), ('block', 'VERB'), ('maintaining', 'VERB'), ('will', 'VERB'), ('be', 'VERB'), ('ca', 'VERB'), ('hold', 'VERB'), ('are', 'VERB'), ('impressed', 'VERB'), ('had', 'VERB'), ('met', 'VERB'), ('fundraising', 'VERB'), ('represent', 'VERB'), ('said', 'VERB'), ('make', 'VERB'), ('falling', 'VERB'), ('said', 'VERB'), ('would', 'VERB'), ('follow', 'VERB'), ('Says', 'VERB'), ('is', 'VERB'), ('needed', 'VERB'), ('was', 'VERB'), ('are', 'VERB'), ('going', 'VERB'), ('have', 'VERB'), ('proposed', 'VERB'), ('say', 'VERB'), ('would', 'VERB'), ('take', 'VERB'), ('enjoy', 'VERB'), ('do', 'VERB'), ('placed', 'VERB'), ('fixed', 'VERB'), ('Hold', 'VERB'), ('must', 'VERB'), ('attempt', 'VERB'), ('reach', 'VERB'), ('has', 'VERB'), ('opposed', 'VERB'), ('soared', 'VERB'), ('following', 'VERB'), ('reacted', 'VERB'), ('seeks', 'VERB'), ('take', 'VERB'), ('has', 'VERB'), ('set', 'VERB'), ('sold', 'VERB'), ('Says', 'VERB'), ('is', 'VERB'), ('has', 'VERB'), ('faced', 'VERB'), ('entitles', 'VERB'), ('buy', 'VERB'), ('warrants', 'VERB'), ('buy', 'VERB'), ('implied', 'VERB'), ('had', 'VERB'), ('discovered', 'VERB'), ('is', 'VERB'), ('be', 'VERB'), ('found', 'VERB'), ('is', 'VERB'), ('takes', 'VERB'), ('rose', 'VERB'), ('changed', 'VERB'), ('is', 'VERB'), ('trying', 'VERB'), ('entice', 'VERB'), ('negotiating', 'VERB'), ('talking', 'VERB'), ('has', 'VERB'), ('revived', 'VERB'), ('called', 'VERB'), ('say', 'VERB'), ('is', 'VERB'), ('might', 'VERB'), ('have', 'VERB'), ('been', 'VERB'), ('estimated', 'VERB'), ('will', 'VERB'), ('result', 'VERB'), ('began', 'VERB'), ('build', 'VERB'), ('will', 'VERB'), ('require', 'VERB'), ('develop', 'VERB'), ('possess', 'VERB'), ('can', 'VERB'), ('be', 'VERB'), ('developed', 'VERB'), ('said', 'VERB'), ('could', 'VERB'), ('be', 'VERB'), ('be', 'VERB'), ('removed', 'VERB'), ('craft', 'VERB'), ('received', 'VERB'), ('are', 'VERB'), ('working', 'VERB'), ('is', 'VERB'), ('accept', 'VERB'), ('comes', 'VERB'), ('planned', 'VERB'), ('did', 'VERB'), ('involve', 'VERB'), ('added', 'VERB'), ('seemed', 'VERB'), ('torn', 'VERB'), ('keeping', 'VERB'), ('trying', 'VERB'), ('provide', 'VERB'), ('staid', 'VERB'), ('said', 'VERB'), ('will', 'VERB'), ('be', 'VERB'), ('forces', 'VERB'), ('become', 'VERB'), ('said', 'VERB'), ('are', 'VERB'), ('justify', 'VERB'), ('pay', 'VERB'), ('refuse', 'VERB'), ('pay', 'VERB'), ("'re", 'VERB'), ('seeing', 'VERB'), ('are', 'VERB'), ('growing', 'VERB'), ('contributed', 'VERB'), ('breaks', 'VERB'), ('prolonged', 'VERB'), ('is', 'VERB'), ('are', 'VERB'), ('keeping', 'VERB'), ('rose', 'VERB'), ('is', 'VERB'), ('could', 'VERB'), ('bring', 'VERB'), ('run', 'VERB'), ('left', 'VERB'), ('run', 'VERB'), ('owned', 'VERB'), ('have', 'VERB'), ('been', 'VERB'), ('noted', 'VERB'), ('said', 'VERB'), ('is', 'VERB'), ('matched', 'VERB'), ('resulted', 'VERB'), ('needed', 'VERB'), ('remove', 'VERB'), ('is', 'VERB'), ('wrestling', 'VERB'), ('can', 'VERB'), ('do', 'VERB'), ("'re", 'VERB'), ('get', 'VERB'), ('represents', 'VERB'), ('say', 'VERB'), ('picked', 'VERB'), ('hauled', 'VERB'), ('rose', 'VERB'), ('gaining', 'VERB'), ('Am', 'VERB'), ('has', 'VERB'), ('subpoenaed', 'VERB'), ('including', 'VERB'), ('determine', 'VERB'), ('were', 'VERB'), ('warned', 'VERB'), ('had', 'VERB'), ('been', 'VERB'), ('planted', 'VERB'), ('exploded', 'VERB'), ('killing', 'VERB'), ('could', 'VERB'), ('make', 'VERB'), ('welcomed', 'VERB'), ('boosted', 'VERB'), ('said', 'VERB'), ('believes', 'VERB'), ('will', 'VERB'), ('turn', 'VERB'), ("'s", 'VERB'), ('oriented', 'VERB'), ('has', 'VERB'), ('weigh', 'VERB'), ('can', 'VERB'), ('earn', 'VERB'), ('making', 'VERB'), ('produce', 'VERB'), ('said', 'VERB'), ('rose', 'VERB'), ...
# (28, 10860)

# %% [markdown]
# # Compute  Transition Probability

# %%
train_tagged_words[:5]
# Out:
# [('Drink', 'NOUN'),
#  ('Carrier', 'NOUN'),
#  ('Competes', 'VERB'),
#  ('With', 'ADP'),
#  ('Cartons', 'NOUN')]

# %%
def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
Verb_Follows_by_Noun = t2_given_t1('NOUN', 'VERB')
Verb_Follows_by_Noun
# Out:
# (1201, 10860)

# %%
Verb_Follows_by_Noun[0]/Verb_Follows_by_Noun[1]
# Out:
# 0.11058931860036833

# %%
Noun_Follows_by_ADJ = t2_given_t1('ADJ', 'NOUN')
Noun_Follows_by_ADJ
# Out:
# (289, 22966)

# %%
Noun_Follows_by_ADJ[0]/Noun_Follows_by_ADJ[1]
# Out:
# 0.012583819559348602

# %%
tags = {tag for word,tag in train_tagged_words}
print(len(tags))
print(tags)
# Out:
# 12
# {'PRON', 'ADV', 'DET', '.', 'NOUN', 'X', 'PRT', 'ADP', 'CONJ', 'VERB', 'ADJ', 'NUM'}

# %% [markdown]
# # creating t x t transition matrix of tags, t= no of tags
# # Matrix(i, j) represents P(jth tag after the ith tag)

# %%
tags_matrix = np.zeros((len(tags), len(tags)), dtype='float32')
for i, t1 in enumerate(list(tags)):
    for j, t2 in enumerate(list(tags)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]
 
print(tags_matrix)
# Out:
# [[6.83371304e-03 3.69020514e-02 9.56719834e-03 4.19134386e-02
#   2.12756261e-01 8.83826911e-02 1.41230067e-02 2.23234631e-02
#   5.01138950e-03 4.84738052e-01 7.06150308e-02 6.83371304e-03]
#  [1.20248254e-02 8.14584941e-02 7.13731572e-02 1.39255241e-01
#   3.21955010e-02 2.28859577e-02 1.47401085e-02 1.19472459e-01
#   6.98215654e-03 3.39022487e-01 1.30721495e-01 2.98681147e-02]
#  [3.30602261e-03 1.20741697e-02 6.03708485e-03 1.73925534e-02
#   6.35906279e-01 4.51343954e-02 2.87480245e-04 9.91806854e-03
#   4.31220367e-04 4.02472317e-02 2.06410810e-01 2.28546783e-02]
#  [6.87694475e-02 5.25694676e-02 1.72191828e-01 9.23720598e-02
#   2.18538776e-01 2.56410260e-02 2.78940029e-03 9.29084867e-02
#   6.00793920e-02 8.96899477e-02 4.61323895e-02 7.82104954e-02]
#  [4.65906132e-03 1.68945398e-02 1.31063312e-02 2.40094051e-01
#   2.62344331e-01 2.88252197e-02 4.39345129e-02 1.76826611e-01
#   4.24540639e-02 1.49133503e-01 1.25838192e-02 9.14395228e-03]
#  [5.41995019e-02 2.57543717e-02 5.68902567e-02 1.60868734e-01
#   6.16951771e-02 7.57255405e-02 1.85085520e-01 1.42225638e-01
#   1.03786280e-02 2.06419379e-01 1.76821072e-02 3.07514891e-03]
#  [1.76125243e-02 9.39334650e-03 1.01369865e-01 4.50097844e-02
#   2.50489235e-01 1.21330721e-02 1.17416831e-03 1.95694715e-02
#   2.34833662e-03 4.01174158e-01 8.29745606e-02 5.67514673e-02]
#  [6.96026310e-02 1.45532778e-02 3.20931405e-01 3.87243740e-02
#   3.23588967e-01 3.45482156e-02 1.26550242e-03 1.69577319e-02
#   1.01240189e-03 8.47886596e-03 1.07061505e-01 6.32751212e-02]
#  [6.03732169e-02 5.70801310e-02 1.23490669e-01 3.51262353e-02
#   3.49066973e-01 9.33040585e-03 4.39077942e-03 5.59824370e-02
#   5.48847427e-04 1.50384188e-01 1.13611415e-01 4.06147093e-02]
#  [3.55432779e-02 8.38858187e-02 1.33609578e-01 3.48066315e-02
#   1.10589318e-01 2.15930015e-01 3.06629837e-02 9.23572779e-02
#   5.43278083e-03 1.67955801e-01 6.63904250e-02 2.28360966e-02]
#  [1.94174761e-04 5.24271838e-03 5.24271838e-03 6.60194159e-02
#   6.96893215e-01 2.09708735e-02 1.14563107e-02 8.05825219e-02
#   1.68932043e-02 1.14563107e-02 6.33009672e-02 2.17475723e-02]
#  [1.42806140e-03 3.57015361e-03 3.57015361e-03 1.19243130e-01
#   3.51660132e-01 2.02427700e-01 2.60621198e-02 3.74866128e-02
#   1.42806144e-02 2.07068902e-02 3.53445187e-02 1.84219927e-01]]

# %% [markdown]
# # convert the matrix to a df for better readability
# # the table is same as the transition table shown in section 3 of article

# %%
tags_df = pd.DataFrame(tags_matrix, columns = list(tags), index=list(tags))
display(tags_df)
# Out:
#           PRON       ADV       DET         .      NOUN         X       PRT  \
# PRON  0.006834  0.036902  0.009567  0.041913  0.212756  0.088383  0.014123
# ADV   0.012025  0.081458  0.071373  0.139255  0.032196  0.022886  0.014740
# DET   0.003306  0.012074  0.006037  0.017393  0.635906  0.045134  0.000287
# .     0.068769  0.052569  0.172192  0.092372  0.218539  0.025641  0.002789
# NOUN  0.004659  0.016895  0.013106  0.240094  0.262344  0.028825  0.043935
# X     0.054200  0.025754  0.056890  0.160869  0.061695  0.075726  0.185086
# PRT   0.017613  0.009393  0.101370  0.045010  0.250489  0.012133  0.001174
# ADP   0.069603  0.014553  0.320931  0.038724  0.323589  0.034548  0.001266
# CONJ  0.060373  0.057080  0.123491  0.035126  0.349067  0.009330  0.004391
# VERB  0.035543  0.083886  0.133610  0.034807  0.110589  0.215930  0.030663
# ADJ   0.000194  0.005243  0.005243  0.066019  0.696893  0.020971  0.011456
# NUM   0.001428  0.003570  0.003570  0.119243  0.351660  0.202428  0.026062
#
#            ADP      CONJ      VERB       ADJ       NUM
# PRON  0.022323  0.005011  0.484738  0.070615  0.006834
# ADV   0.119472  0.006982  0.339022  0.130721  0.029868
# DET   0.009918  0.000431  0.040247  0.206411  0.022855
# .     0.092908  0.060079  0.089690  0.046132  0.078210
# NOUN  0.176827  0.042454  0.149134  0.012584  0.009144
# X     0.142226  0.010379  0.206419  0.017682  0.003075
# PRT   0.019569  0.002348  0.401174  0.082975  0.056751
# ADP   0.016958  0.001012  0.008479  0.107062  0.063275
# CONJ  0.055982  0.000549  0.150384  0.113611  0.040615
# VERB  0.092357  0.005433  0.167956  0.066390  0.022836
# ADJ   0.080583  0.016893  0.011456  0.063301  0.021748
# NUM   0.037487  0.014281  0.020707  0.035345  0.184220

# %%
def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
     
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                 
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
             
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
# Out:
# 0.001785793392

# %%
train_tagged_words
# Out:
# [('Drink', 'NOUN'),
#  ('Carrier', 'NOUN'),
#  ('Competes', 'VERB'),
#  ('With', 'ADP'),
#  ('Cartons', 'NOUN'),
#  ('At', 'ADP'),
#  ('last', 'ADJ'),
#  ('count', 'NOUN'),
#  (',', '.'),
#  ('Candela', 'NOUN'),
#  ('had', 'VERB'),
#  ('sold', 'VERB'),
#  ('$', '.'),
#  ('4', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('of', 'ADP'),
#  ('its', 'PRON'),
#  ('medical', 'ADJ'),
#  ('devices', 'NOUN'),
#  ('in', 'ADP'),
#  ('Japan', 'NOUN'),
#  ('.', '.'),
#  ('Mrs.', 'NOUN'),
#  ('Hills', 'NOUN'),
#  ('lauded', 'VERB'),
#  ('South', 'NOUN'),
#  ('Korea', 'NOUN'),
#  ('for', 'ADP'),
#  ('*-1', 'X'),
#  ('creating', 'VERB'),
#  ('an', 'DET'),
#  ('intellectual-property', 'ADJ'),
#  ('task', 'NOUN'),
#  ('force', 'NOUN'),
#  ('and', 'CONJ'),
#  ('special', 'ADJ'),
#  ('enforcement', 'NOUN'),
#  ('teams', 'NOUN'),
#  ('of', 'ADP'),
#  ('police', 'NOUN'),
#  ('officers', 'NOUN'),
#  ('and', 'CONJ'),
#  ('prosecutors', 'NOUN'),
#  ('trained', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('pursue', 'VERB'),
#  ('movie', 'NOUN'),
#  ('and', 'CONJ'),
#  ('book', 'NOUN'),
#  ('pirates', 'NOUN'),
#  ('.', '.'),
#  ('Section', 'NOUN'),
#  ('501', 'NUM'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('United', 'NOUN'),
#  ('States', 'NOUN'),
#  ('Information', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Educational', 'NOUN'),
#  ('Exchange', 'NOUN'),
#  ('Act', 'NOUN'),
#  ('of', 'ADP'),
#  ('1948', 'NUM'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('Voice', 'NOUN'),
#  ('material', 'NOUN'),
#  ('shall', 'VERB'),
#  ('be', 'VERB'),
#  ('available', 'ADJ'),
#  ('to', 'PRT'),
#  ('certain', 'ADJ'),
#  ('of', 'ADP'),
#  ('us', 'PRON'),
#  ('-LRB-', '.'),
#  ('but', 'CONJ'),
#  ('now', 'ADV'),
#  (',', '.'),
#  ('thanks', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('USIA', 'NOUN'),
#  ("'s", 'PRT'),
#  ('new', 'ADJ'),
#  ('position', 'NOUN'),
#  (',', '.'),
#  ('all', 'DET'),
#  ('of', 'ADP'),
#  ('us', 'PRON'),
#  ('-RRB-', '.'),
#  ('``', '.'),
#  ('for', 'ADP'),
#  ('examination', 'NOUN'),
#  ('only', 'ADV'),
#  ('.', '.'),
#  ("''", '.'),
#  ('A', 'DET'),
#  ('Lorillard', 'NOUN'),
#  ('spokewoman', 'NOUN'),
#  ('said', 'VERB'),
#  (',', '.'),
#  ('``', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('old', 'ADJ'),
#  ('story', 'NOUN'),
#  ('.', '.'),
#  ('Timex', 'NOUN'),
#  ('had', 'VERB'),
#  ('requested', 'VERB'),
#  ('duty-free', 'ADJ'),
#  ('treatment', 'NOUN'),
#  ('for', 'ADP'),
#  ('many', 'ADJ'),
#  ('types', 'NOUN'),
#  ('of', 'ADP'),
#  ('watches', 'NOUN'),
#  (',', '.'),
#  ('covered', 'VERB'),
#  ('*', 'X'),
#  ('by', 'ADP'),
#  ('58', 'NUM'),
#  ('different', 'ADJ'),
#  ('U.S.', 'NOUN'),
#  ('tariff', 'NOUN'),
#  ('classifications', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('House', 'NOUN'),
#  ('passed', 'VERB'),
#  ('legislation', 'NOUN'),
#  ('designed', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('make', 'VERB'),
#  ('it', 'PRON'),
#  ('easier', 'ADJ'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('Transportation', 'NOUN'),
#  ('Department', 'NOUN'),
#  ('to', 'PRT'),
#  ('block', 'VERB'),
#  ('airline', 'NOUN'),
#  ('leveraged', 'ADJ'),
#  ('buy-outs', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('*', 'X'),
#  ('maintaining', 'VERB'),
#  ('U.S.', 'NOUN'),
#  ('influence', 'NOUN'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('difficult', 'ADJ'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('face', 'NOUN'),
#  ('of', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('dominance', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('region', 'NOUN'),
#  ('.', '.'),
#  ('You', 'PRON'),
#  ('ca', 'VERB'),
#  ("n't", 'ADV'),
#  ('hold', 'VERB'),
#  ('back', 'ADJ'),
#  ('technology', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Some', 'DET'),
#  ('of', 'ADP'),
#  ('his', 'PRON'),
#  ('observations', 'NOUN'),
#  ('about', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('management', 'NOUN'),
#  ('style', 'NOUN'),
#  ('are', 'VERB'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('mark', 'NOUN'),
#  ('.', '.'),
#  ('That', 'DET'),
#  ('impressed', 'VERB'),
#  ('Robert', 'NOUN'),
#  ('B.', 'NOUN'),
#  ('Pamplin', 'NOUN'),
#  (',', '.'),
#  ('Georgia-Pacific', 'NOUN'),
#  ("'s", 'PRT'),
#  ('chief', 'NOUN'),
#  ('executive', 'ADJ'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  ('time', 'NOUN'),
#  (',', '.'),
#  ('whom', 'PRON'),
#  ('Mr.', 'NOUN'),
#  ('Hahn', 'NOUN'),
#  ('had', 'VERB'),
#  ('met', 'VERB'),
#  ('*T*-4', 'X'),
#  ('while', 'ADP'),
#  ('*-1', 'X'),
#  ('fundraising', 'VERB'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('institute', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('These', 'DET'),
#  ('two', 'NUM'),
#  ('exposures', 'NOUN'),
#  ('alone', 'ADV'),
#  ('represent', 'VERB'),
#  ('a', 'DET'),
#  ('very', 'ADV'),
#  ('substantial', 'ADJ'),
#  ('portion', 'NOUN'),
#  ('of', 'ADP'),
#  ('CS', 'NOUN'),
#  ('First', 'NOUN'),
#  ('Boston', 'NOUN'),
#  ("'s", 'PRT'),
#  ('equity', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('Moody', 'NOUN'),
#  ("'s", 'PRT'),
#  ('said', 'VERB'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('Asian', 'ADJ'),
#  ('nations', 'NOUN'),
#  ("'", 'PRT'),
#  ('harsh', 'ADJ'),
#  ('memories', 'NOUN'),
#  ('of', 'ADP'),
#  ('their', 'PRON'),
#  ('military', 'ADJ'),
#  ('domination', 'NOUN'),
#  ('by', 'ADP'),
#  ('Japan', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('early', 'ADJ'),
#  ('part', 'NOUN'),
#  ('of', 'ADP'),
#  ('this', 'DET'),
#  ('century', 'NOUN'),
#  ('make', 'VERB'),
#  ('them', 'PRON'),
#  ('fearful', 'ADJ'),
#  ('of', 'ADP'),
#  ('*', 'X'),
#  ('falling', 'VERB'),
#  ('under', 'ADP'),
#  ('Japanese', 'ADJ'),
#  ('economic', 'ADJ'),
#  ('hegemony', 'NOUN'),
#  ('now', 'ADV'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('Communist', 'NOUN'),
#  ('Party', 'NOUN'),
#  ('chief', 'NOUN'),
#  (',', '.'),
#  ('*-1', 'X'),
#  ('in', 'ADP'),
#  ('Moscow', 'NOUN'),
#  ('for', 'ADP'),
#  ('talks', 'NOUN'),
#  ('with', 'ADP'),
#  ('Soviet', 'ADJ'),
#  ('officials', 'NOUN'),
#  (',', '.'),
#  ('also', 'ADV'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('East', 'NOUN'),
#  ('Germany', 'NOUN'),
#  ('would', 'VERB'),
#  ('follow', 'VERB'),
#  ('Gorbachev', 'NOUN'),
#  ("'s", 'PRT'),
#  ('restructuring', 'NOUN'),
#  ('plans', 'NOUN'),
#  ('.', '.'),
#  ('Says', 'VERB'),
#  ('*ICH*-1', 'X'),
#  ('the', 'DET'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ("'s", 'PRT'),
#  ('Mr.', 'NOUN'),
#  ('Phelan', 'NOUN'),
#  (',', '.'),
#  ('``', '.'),
#  ('Volatility', 'NOUN'),
#  ('is', 'VERB'),
#  ('greater', 'ADJ'),
#  ('than', 'ADP'),
#  ('program', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('last', 'ADJ'),
#  ('thing', 'NOUN'),
#  ('0', 'X'),
#  ('they', 'PRON'),
#  ('needed', 'VERB'),
#  ('*T*-1', 'X'),
#  ('was', 'VERB'),
#  ('another', 'DET'),
#  ('drag-down', 'ADJ'),
#  ('blow', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('But', 'CONJ'),
#  ('we', 'PRON'),
#  ('are', 'VERB'),
#  ('not', 'ADV'),
#  ('going', 'VERB'),
#  ('back', 'ADV'),
#  ('to', 'PRT'),
#  ('1970', 'NUM'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Short', 'ADJ'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('total', 'NOUN'),
#  ('ban', 'NOUN'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('anti-programmers', 'NOUN'),
#  ('have', 'VERB'),
#  ('proposed', 'VERB'),
#  ('several', 'ADJ'),
#  ('middle-ground', 'ADJ'),
#  ('reforms', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('they', 'PRON'),
#  ('say', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('would', 'VERB'),
#  ('take', 'VERB'),
#  ('away', 'PRT'),
#  ('certain', 'ADJ'),
#  ('advantages', 'NOUN'),
#  ('0', 'X'),
#  ('program', 'NOUN'),
#  ('traders', 'NOUN'),
#  ('currently', 'ADV'),
#  ('enjoy', 'VERB'),
#  ('*T*-2', 'X'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('marketplace', 'NOUN'),
#  ('that', 'ADP'),
#  ('other', 'ADJ'),
#  ('investors', 'NOUN'),
#  ('do', 'VERB'),
#  ("n't", 'ADV'),
#  ('*T*-3', 'X'),
#  ('.', '.'),
#  ('60', 'NUM'),
#  ('million', 'NUM'),
#  ('Swiss', 'ADJ'),
#  ('francs', 'NOUN'),
#  ('of', 'ADP'),
#  ('privately', 'ADV'),
#  ('placed', 'VERB'),
#  ('convertible', 'ADJ'),
#  ('notes', 'NOUN'),
#  ('due', 'ADJ'),
#  ('Dec.', 'NOUN'),
#  ('31', 'NUM'),
#  (',', '.'),
#  ('1993', 'NUM'),
#  (',', '.'),
#  ('with', 'ADP'),
#  ('a', 'DET'),
#  ('fixed', 'VERB'),
#  ('0.25', 'NUM'),
#  ('%', 'NOUN'),
#  ('coupon', 'NOUN'),
#  ('at', 'ADP'),
#  ('par', 'NOUN'),
#  ('via', 'ADP'),
#  ('Union', 'NOUN'),
#  ('Bank', 'NOUN'),
#  ('of', 'ADP'),
#  ('Switzerland', 'NOUN'),
#  ('.', '.'),
#  ('*', 'X'),
#  ('Hold', 'VERB'),
#  ('the', 'DET'),
#  ('Putty', 'NOUN'),
#  ('!', '.'),
#  ('But', 'CONJ'),
#  ('any', 'DET'),
#  ('potential', 'ADJ'),
#  ('acquirer', 'NOUN'),
#  ('must', 'VERB'),
#  ('attempt', 'VERB'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('reach', 'VERB'),
#  ('some', 'DET'),
#  ('kind', 'NOUN'),
#  ('of', 'ADP'),
#  ('accord', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ("'s", 'PRT'),
#  ('employees', 'NOUN'),
#  (',', '.'),
#  ('primarily', 'ADV'),
#  ('its', 'PRON'),
#  ('pilots', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('powerful', 'ADJ'),
#  ('machinists', 'NOUN'),
#  ("'", 'PRT'),
#  ('union', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-1', 'X'),
#  ('has', 'VERB'),
#  ('opposed', 'VERB'),
#  ('a', 'DET'),
#  ('takeover', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('1976', 'NUM'),
#  (',', '.'),
#  ('for', 'ADP'),
#  ('example', 'NOUN'),
#  (',', '.'),
#  ('dividends', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('stocks', 'NOUN'),
#  ('in', 'ADP'),
#  ('Standard', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Poor', 'NOUN'),
#  ("'s", 'PRT'),
#  ('500-stock', 'ADJ'),
#  ('index', 'NOUN'),
#  ('soared', 'VERB'),
#  ('10', 'NUM'),
#  ('%', 'NOUN'),
#  (',', '.'),
#  ('following', 'VERB'),
#  ('much', 'ADV'),
#  ('slower', 'ADJ'),
#  ('growth', 'NOUN'),
#  ('the', 'DET'),
#  ('year', 'NOUN'),
#  ('before', 'ADP'),
#  ('.', '.'),
#  ('Wall', 'NOUN'),
#  ('Street', 'NOUN'),
#  ('reacted', 'VERB'),
#  ('favorably', 'ADV'),
#  ('to', 'PRT'),
#  ('Mr.', 'NOUN'),
#  ('McGovern', 'NOUN'),
#  ("'s", 'PRT'),
#  ('departure', 'NOUN'),
#  ('and', 'CONJ'),
#  ('its', 'PRON'),
#  ('implications', 'NOUN'),
#  ('.', '.'),
#  ('Like', 'ADP'),
#  ('other', 'ADJ'),
#  ('forms', 'NOUN'),
#  ('of', 'ADP'),
#  ('arbitrage', 'NOUN'),
#  (',', '.'),
#  ('it', 'PRON'),
#  ('merely', 'ADV'),
#  ('seeks', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('take', 'VERB'),
#  ('advantage', 'NOUN'),
#  ('of', 'ADP'),
#  ('momentary', 'ADJ'),
#  ('discrepancies', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('single', 'ADJ'),
#  ('product', 'NOUN'),
#  ('--', '.'),
#  ('in', 'ADP'),
#  ('this', 'DET'),
#  ('case', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('basket', 'NOUN'),
#  ('of', 'ADP'),
#  ('stocks', 'NOUN'),
#  ('--', '.'),
#  ('in', 'ADP'),
#  ('different', 'ADJ'),
#  ('markets', 'NOUN'),
#  ('--', '.'),
#  ('in', 'ADP'),
#  ('this', 'DET'),
#  ('case', 'NOUN'),
#  ('the', 'DET'),
#  ('New', 'NOUN'),
#  ('York', 'NOUN'),
#  ('Stock', 'NOUN'),
#  ('Exchange', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('Chicago', 'NOUN'),
#  ('futures', 'NOUN'),
#  ('markets', 'NOUN'),
#  ('.', '.'),
#  ('Britain', 'NOUN'),
#  ('has', 'VERB'),
#  ('two', 'NUM'),
#  ('main', 'ADJ'),
#  ('index-arbitrage', 'NOUN'),
#  ('instruments', 'NOUN'),
#  ('.', '.'),
#  ('A', 'DET'),
#  ('painting', 'NOUN'),
#  ('by', 'ADP'),
#  ('August', 'NOUN'),
#  ('Strindberg', 'NOUN'),
#  ('set', 'VERB'),
#  ('a', 'DET'),
#  ('Scandinavian', 'ADJ'),
#  ('price', 'NOUN'),
#  ('record', 'NOUN'),
#  ('when', 'ADV'),
#  ('it', 'PRON'),
#  ('sold', 'VERB'),
#  ('at', 'ADP'),
#  ('auction', 'NOUN'),
#  ('in', 'ADP'),
#  ('Stockholm', 'NOUN'),
#  ('for', 'ADP'),
#  ('$', '.'),
#  ('2.44', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Says', 'VERB'),
#  ('*ICH*-1', 'X'),
#  ('Kathryn', 'NOUN'),
#  ('McAuley', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('analyst', 'NOUN'),
#  ('at', 'ADP'),
#  ('First', 'NOUN'),
#  ('Manhattan', 'NOUN'),
#  ('Co.', 'NOUN'),
#  (':', '.'),
#  ('``', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('greatest', 'ADJ'),
#  ('acquisition', 'NOUN'),
#  ('challenge', 'NOUN'),
#  ('0', 'X'),
#  ('he', 'PRON'),
#  ('has', 'VERB'),
#  ('faced', 'VERB'),
#  ('*T*-2', 'X'),
#  ('.', '.'),
#  ('Each', 'DET'),
#  ('right', 'NOUN'),
#  ('entitles', 'VERB'),
#  ('the', 'DET'),
#  ('shareholder', 'NOUN'),
#  ('to', 'PRT'),
#  ('buy', 'VERB'),
#  ('$', '.'),
#  ('100', 'NUM'),
#  ('*U*', 'X'),
#  ('face', 'NOUN'),
#  ('amount', 'NOUN'),
#  ('of', 'ADP'),
#  ('13.5', 'NUM'),
#  ('%', 'NOUN'),
#  ('bonds', 'NOUN'),
#  ('due', 'ADJ'),
#  ('1993', 'NUM'),
#  ('and', 'CONJ'),
#  ('warrants', 'VERB'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('buy', 'VERB'),
#  ('23.5', 'NUM'),
#  ('common', 'ADJ'),
#  ('shares', 'NOUN'),
#  ('at', 'ADP'),
#  ('30', 'NUM'),
#  ('cents', 'NOUN'),
#  ('a', 'DET'),
#  ('share', 'NOUN'),
#  ('.', '.'),
#  ('Your', 'PRON'),
#  ('comments', 'NOUN'),
#  ('implied', 'VERB'),
#  ('0', 'X'),
#  ('we', 'PRON'),
#  ('had', 'VERB'),
#  ('discovered', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('``', '.'),
#  ('principal', 'ADJ'),
#  ('cause', 'NOUN'),
#  ("''", '.'),
#  ('of', 'ADP'),
#  ('homelessness', 'NOUN'),
#  ('is', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('found', 'VERB'),
#  ('*-18', 'X'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('large', 'ADJ'),
#  ('numbers', 'NOUN'),
#  ('of', 'ADP'),
#  ('mentally', 'ADV'),
#  ('ill', 'ADJ'),
#  ('and', 'CONJ'),
#  ('substance-abusing', 'ADJ'),
#  ('people', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('homeless', 'ADJ'),
#  ('population', 'NOUN'),
#  ('.', '.'),
#  ('A', 'DET'),
#  ('series', 'NOUN'),
#  ('of', 'ADP'),
#  ('5,000', 'NUM'),
#  ('or', 'CONJ'),
#  ('so', 'ADV'),
#  ('changes', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('``', '.'),
#  ('peal', 'NOUN'),
#  ("''", '.'),
#  ('and', 'CONJ'),
#  ('takes', 'VERB'),
#  ('about', 'ADV'),
#  ('three', 'NUM'),
#  ('hours', 'NOUN'),
#  ('.', '.'),
#  ('Texaco', 'NOUN'),
#  ('rose', 'VERB'),
#  ('3\\/4', 'NUM'),
#  ('to', 'PRT'),
#  ('53', 'NUM'),
#  ('3\\/8', 'NUM'),
#  ('as', 'ADP'),
#  ('4.4', 'NUM'),
#  ('million', 'NUM'),
#  ('shares', 'NOUN'),
#  ('changed', 'VERB'),
#  ('hands', 'NOUN'),
#  ('.', '.'),
#  ('So', 'ADP'),
#  ('far', 'ADV'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Hahn', 'NOUN'),
#  ('is', 'VERB'),
#  ('trying', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('entice', 'VERB'),
#  ('Nekoosa', 'NOUN'),
#  ('into', 'ADP'),
#  ('*', 'X'),
#  ('negotiating', 'VERB'),
#  ('a', 'DET'),
#  ('friendly', 'ADJ'),
#  ('surrender', 'NOUN'),
#  ('while', 'ADP'),
#  ('*-1', 'X'),
#  ('talking', 'VERB'),
#  ('tough', 'ADJ'),
#  ('.', '.'),
#  ('Now', 'ADV'),
#  (',', '.'),
#  ('13', 'NUM'),
#  ('years', 'NOUN'),
#  ('later', 'ADV'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Lane', 'NOUN'),
#  ('has', 'VERB'),
#  ('revived', 'VERB'),
#  ('his', 'PRON'),
#  ('Artist', 'NOUN'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('full-length', 'ADJ'),
#  ('movie', 'NOUN'),
#  ('called', 'VERB'),
#  ('*', 'X'),
#  ('``', '.'),
#  ('Sidewalk', 'NOUN'),
#  ('Stories', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('a', 'DET'),
#  ('poignant', 'ADJ'),
#  ('piece', 'NOUN'),
#  ('of', 'ADP'),
#  ('work', 'NOUN'),
#  ('about', 'ADP'),
#  ('a', 'DET'),
#  ('modern-day', 'ADJ'),
#  ('tramp', 'NOUN'),
#  ('.', '.'),
#  ('Still', 'ADV'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('market', 'NOUN'),
#  ('analysts', 'NOUN'),
#  ('say', 'VERB'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('current', 'ADJ'),
#  ('3.3', 'NUM'),
#  ('%', 'NOUN'),
#  ('reading', 'NOUN'),
#  ('is', 'VERB'),
#  ("n't", 'ADV'),
#  ('as', 'ADV'),
#  ('troublesome', 'ADJ'),
#  ('as', 'ADP'),
#  ('it', 'PRON'),
#  ('might', 'VERB'),
#  ('have', 'VERB'),
#  ('been', 'VERB'),
#  ('*?*', 'X'),
#  ('in', 'ADP'),
#  ('years', 'NOUN'),
#  ('past', 'NOUN'),
#  ('.', '.'),
#  ('Travelers', 'NOUN'),
#  ('estimated', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('California', 'NOUN'),
#  ('earthquake', 'NOUN'),
#  ('last', 'ADJ'),
#  ('month', 'NOUN'),
#  ('will', 'VERB'),
#  ('result', 'VERB'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('fourth-quarter', 'NOUN'),
#  ('pre-tax', 'ADJ'),
#  ('charge', 'NOUN'),
#  ('of', 'ADP'),
#  ('less', 'ADJ'),
#  ('than', 'ADP'),
#  ('$', '.'),
#  ('10', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('Pressures', 'NOUN'),
#  ('began', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('build', 'VERB'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('will', 'VERB'),
#  ('require', 'VERB'),
#  ('us', 'PRON'),
#  ('to', 'PRT'),
#  ('develop', 'VERB'),
#  ('a', 'DET'),
#  ('much', 'ADV'),
#  ('more', 'ADV'),
#  ('sophisticated', 'ADJ'),
#  ('understanding', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('dynamics', 'NOUN'),
#  ('of', 'ADP'),
#  ('homelessness', 'NOUN'),
#  ('than', 'ADP'),
#  ('we', 'PRON'),
#  ('currently', 'ADV'),
#  ('possess', 'VERB'),
#  ('*?*', 'X'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('understanding', 'NOUN'),
#  ('that', 'DET'),
#  ('*T*-1', 'X'),
#  ('can', 'VERB'),
#  ('be', 'VERB'),
#  ('developed', 'VERB'),
#  ('*-20', 'X'),
#  ('only', 'ADV'),
#  ('through', 'ADP'),
#  ('careful', 'ADJ'),
#  ('study', 'NOUN'),
#  ('and', 'CONJ'),
#  ('research', 'NOUN'),
#  ('.', '.'),
#  ('He', 'PRON'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('Mexico', 'NOUN'),
#  ('could', 'VERB'),
#  ('be', 'VERB'),
#  ('one', 'NUM'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('next', 'ADJ'),
#  ('countries', 'NOUN'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('removed', 'VERB'),
#  ('*-2', 'X'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('priority', 'NOUN'),
#  ('list', 'NOUN'),
#  ('because', 'ADP'),
#  ('of', 'ADP'),
#  ('its', 'PRON'),
#  ('efforts', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('craft', 'VERB'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('patent', 'NOUN'),
#  ('law', 'NOUN'),
#  ('.', '.'),
#  ('Georgia', 'NOUN'),
#  ('Gulf', 'NOUN'),
#  ('received', 'VERB'),
#  ('a', 'DET'),
#  ('new', 'ADJ'),
#  ('takeover', 'NOUN'),
#  ('bid', 'NOUN'),
#  ('*ICH*-1', 'X'),
#  ('from', 'ADP'),
#  ('investor', 'NOUN'),
#  ('Harold', 'NOUN'),
#  ('Simmons', 'NOUN'),
#  ('and', 'CONJ'),
#  ('NL', 'NOUN'),
#  ('Industries', 'NOUN'),
#  ('of', 'ADP'),
#  ('$', '.'),
#  ('50', 'NUM'),
#  ('*U*', 'X'),
#  ('a', 'DET'),
#  ('share', 'NOUN'),
#  (',', '.'),
#  ('or', 'CONJ'),
#  ('about', 'ADP'),
#  ('$', '.'),
#  ('1.1', 'NUM'),
#  ('billion', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('Three', 'NUM'),
#  ('divisions', 'NOUN'),
#  ('at', 'ADP'),
#  ('American', 'NOUN'),
#  ('Express', 'NOUN'),
#  ('*ICH*-1', 'X'),
#  ('are', 'VERB'),
#  ('working', 'VERB'),
#  ('with', 'ADP'),
#  ('Buick', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('promotion', 'NOUN'),
#  (':', '.'),
#  ('the', 'DET'),
#  ('establishment', 'NOUN'),
#  ('services', 'NOUN'),
#  ('division', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-57', 'X'),
#  ('is', 'VERB'),
#  ('responsible', 'ADJ'),
#  ('for', 'ADP'),
#  ('all', 'DET'),
#  ('merchants', 'NOUN'),
#  ('and', 'CONJ'),
#  ('companies', 'NOUN'),
#  ('that', 'DET'),
#  ('*T*-2', 'X'),
#  ('accept', 'VERB'),
#  ('the', 'DET'),
#  ('card', 'NOUN'),
#  (';', '.'),
#  ('the', 'DET'),
#  ('travel', 'NOUN'),
#  ('division', 'NOUN'),
#  (';', '.'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('merchandise', 'NOUN'),
#  ('sales', 'NOUN'),
#  ('division', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('sale', 'NOUN'),
#  ('comes', 'VERB'),
#  ('in', 'ADP'),
#  ('place', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('planned', 'VERB'),
#  ('initial', 'ADJ'),
#  ('public', 'ADJ'),
#  ('offering', 'NOUN'),
#  ('of', 'ADP'),
#  ('Lentjes', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('matter', 'NOUN'),
#  ('``', '.'),
#  ('did', 'VERB'),
#  ("n't", 'ADV'),
#  ('involve', 'VERB'),
#  ('anybody', 'NOUN'),
#  ("'s", 'PRT'),
#  ('securities', 'NOUN'),
#  ('transactions', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('he', 'PRON'),
#  ('added', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Further', 'ADV'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Herald', 'NOUN'),
#  ('seemed', 'VERB'),
#  ('*-1', 'X'),
#  ('torn', 'VERB'),
#  ('editorially', 'ADV'),
#  ('between', 'ADP'),
#  ('*-3', 'X'),
#  ('keeping', 'VERB'),
#  ('its', 'PRON'),
#  ('old-time', 'ADJ'),
#  ('Hearst', 'NOUN'),
#  ('readership', 'NOUN'),
#  ('--', '.'),
#  ('blue-collar', 'ADJ'),
#  ('and', 'CONJ'),
#  ('sports-oriented', 'ADJ'),
#  ...]

# %%
def Viterbi_check(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
     
    for key, word in enumerate(words):
        print(key,word)
        p = [] 
        print()
        for tag in T:
            print(tag)

# %%
for tag in tags:
    print(tag,"\t",tags_df.loc['.', tag])
# Out:
# PRON 	 0.06876945
# ADV 	 0.052569468
# DET 	 0.17219183
# . 	 0.09237206
# NOUN 	 0.21853878
# X 	 0.025641026
# PRT 	 0.0027894003
# ADP 	 0.09290849
# CONJ 	 0.060079392
# VERB 	 0.08968995
# ADJ 	 0.04613239
# NUM 	 0.078210495

# %%
for tag in tags:
    print(tag,"\t",tags_df.loc['PRON', tag])
# Out:
# PRON 	 0.006833713
# ADV 	 0.03690205
# DET 	 0.009567198
# . 	 0.04191344
# NOUN 	 0.21275626
# X 	 0.08838269
# PRT 	 0.014123007
# ADP 	 0.022323463
# CONJ 	 0.0050113895
# VERB 	 0.48473805
# ADJ 	 0.07061503
# NUM 	 0.006833713

# %%
for tag in tags:
    print(tag,"\t",tags_df.loc['VERB', tag])
# Out:
# PRON 	 0.035543278
# ADV 	 0.08388582
# DET 	 0.13360958
# . 	 0.03480663
# NOUN 	 0.11058932
# X 	 0.21593001
# PRT 	 0.030662984
# ADP 	 0.09235728
# CONJ 	 0.005432781
# VERB 	 0.1679558
# ADJ 	 0.066390425
# NUM 	 0.022836097

# %%
for tag in tags:
    print(tag,"\t",tags_df.loc['DET', tag])
# Out:
# PRON 	 0.0033060226
# ADV 	 0.01207417
# DET 	 0.006037085
# . 	 0.017392553
# NOUN 	 0.6359063
# X 	 0.045134395
# PRT 	 0.00028748024
# ADP 	 0.009918069
# CONJ 	 0.00043122037
# VERB 	 0.04024723
# ADJ 	 0.20641081
# NUM 	 0.022854678

# %%
for tag in tags:
    print(tag,"\t",tags_df.loc['ADJ', tag])
# Out:
# PRON 	 0.00019417476
# ADV 	 0.0052427184
# DET 	 0.0052427184
# . 	 0.066019416
# NOUN 	 0.6968932
# X 	 0.020970874
# PRT 	 0.011456311
# ADP 	 0.08058252
# CONJ 	 0.016893204
# VERB 	 0.011456311
# ADJ 	 0.06330097
# NUM 	 0.021747572

# %%
List_of_words_from_sentence = "He is a good boy".split()
print(List_of_words_from_sentence)
for value in List_of_words_from_sentence:
    print(value)
# Out:
# ['He', 'is', 'a', 'good', 'boy']
# He
# is
# a
# good
# boy

# %%
for tag in tags:
    print(tag)
    emission_p = word_given_tag("He", tag)[0]/word_given_tag("He", tag)[1]
    print(tag,"\t",emission_p)
# Out:
# PRON
# PRON 	 0.025968109339407745
# ADV
# ADV 	 0.0
# DET
# DET 	 0.0
# .
# . 	 0.0
# NOUN
# NOUN 	 0.0
# X
# X 	 0.0
# PRT
# PRT 	 0.0
# ADP
# ADP 	 0.0
# CONJ
# CONJ 	 0.0
# VERB
# VERB 	 0.0
# ADJ
# ADJ 	 0.0
# NUM
# NUM 	 0.0

# %%
for tag in tags:
    print(tag)
    emission_p = word_given_tag("is", tag)[0]/word_given_tag("is", tag)[1]
    print(tag,"\t",emission_p)
# Out:
# PRON
# PRON 	 0.0
# ADV
# ADV 	 0.0
# DET
# DET 	 0.0
# .
# . 	 0.0
# NOUN
# NOUN 	 0.0
# X
# X 	 0.0
# PRT
# PRT 	 0.0
# ADP
# ADP 	 0.0
# CONJ
# CONJ 	 0.0
# VERB
# VERB 	 0.04788213627992634
# ADJ
# ADJ 	 0.0
# NUM
# NUM 	 0.0

# %%
for tag in tags:
    print(tag)
    emission_p = word_given_tag("a", tag)[0]/word_given_tag("a", tag)[1]
    print(tag,"\t",emission_p)
# Out:
# PRON
# PRON 	 0.0
# ADV
# ADV 	 0.0
# DET
# DET 	 0.2140290355038091
# .
# . 	 0.0
# NOUN
# NOUN 	 0.0
# X
# X 	 0.00019219680953296174
# PRT
# PRT 	 0.0
# ADP
# ADP 	 0.00012655024044545685
# CONJ
# CONJ 	 0.0
# VERB
# VERB 	 0.0
# ADJ
# ADJ 	 0.0003883495145631068
# NUM
# NUM 	 0.0

# %%
for tag in tags:
    print(tag)
    emission_p = word_given_tag("boy", tag)[0]/word_given_tag("boy", tag)[1]
    print(tag,"\t",emission_p)
# Out:
# PRON
# PRON 	 0.0
# ADV
# ADV 	 0.0
# DET
# DET 	 0.0
# .
# . 	 0.0
# NOUN
# NOUN 	 4.3542628233040145e-05
# X
# X 	 0.0
# PRT
# PRT 	 0.0
# ADP
# ADP 	 0.0
# CONJ
# CONJ 	 0.0
# VERB
# VERB 	 0.0
# ADJ
# ADJ 	 0.0
# NUM
# NUM 	 0.0

# %%
for tag in tags:
    print(tag)
    emission_p = word_given_tag("good", tag)[0]/word_given_tag("good", tag)[1]
    print(tag,"\t",emission_p)

# %%
0.04788213627992634*0.48473805
# Out:
# 0.023210293370165745

# %%
tags
# Out:
# {'.',
#  'ADJ',
#  'ADP',
#  'ADV',
#  'CONJ',
#  'DET',
#  'NOUN',
#  'NUM',
#  'PRON',
#  'PRT',
#  'VERB',
#  'X'}

# %%
#Check how a sentence is tagged by Viterbi POS taggers
test_sent="He is a good boy"
Viterbi_check(test_sent.split())
# Out:
# 0 He
#
# PRON
# ADV
# DET
# .
# NOUN
# X
# PRT
# ADP
# CONJ
# VERB
# ADJ
# NUM
# 1 is
#
# PRON
# ADV
# DET
# .
# NOUN
# X
# PRT
# ADP
# CONJ
# VERB
# ADJ
# NUM
# 2 a
#
# PRON
# ADV
# DET
# .
# NOUN
# X
# PRT
# ADP
# CONJ
# VERB
# ADJ
# NUM
# 3 good
#
# PRON
# ADV
# DET
# .
# NOUN
# X
# PRT
# ADP
# CONJ
# VERB
# ADJ
# NUM
# 4 boy
#
# PRON
# ADV
# DET
# .
# NOUN
# X
# PRT
# ADP
# CONJ
# VERB
# ADJ
# NUM

# %%
#Check how a sentence is tagged by Viterbi POS taggers
test_sent="He is a good boy"
pred_tags_withoutRules= Viterbi(test_sent.split())
print(pred_tags_withoutRules)
# Out:
# [('He', 'PRON'), ('is', 'VERB'), ('a', 'DET'), ('good', 'ADJ'), ('boy', 'NOUN')]

# %%
test_sent="Kids are playing in the ground"
pred_tags_withoutRules= Viterbi(test_sent.split())
print(pred_tags_withoutRules)
# Out:
# [('Kids', 'PRON'), ('are', 'VERB'), ('playing', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('ground', 'NOUN')]
